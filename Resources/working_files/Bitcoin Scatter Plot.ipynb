# %%
import csv
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the uploaded CSV file to inspect its contents
data = pd.read_csv(r'team-7-project3/Resources/cleaned_data.csv')

# %%
# Display the first few rows of the data to understand its structure
data.head()
# Out:
#    Unnamed: 0   timeOpen                timeClose             timeHigh  \
# 0           0 2025-01-15  2025-01-15 23:59:59.999  2025-01-15 20:22:00
# 1           1 2025-01-14  2025-01-14 23:59:59.999  2025-01-14 09:54:00
# 2           2 2025-01-13  2025-01-13 23:59:59.999  2025-01-13 00:38:00
# 3           3 2025-01-12  2025-01-12 23:59:59.999  2025-01-12 15:23:00
# 4           4 2025-01-11  2025-01-11 23:59:59.999  2025-01-11 21:56:00
#
#                timeLow    name          open           high           low  \
# 0  2025-01-15 00:05:00  2781.0  96534.045969  100697.234363  96501.644393
# 1  2025-01-14 00:46:00  2781.0  94519.007141   97352.664748  94322.154504
# 2  2025-01-13 14:37:00  2781.0  94488.892174   95837.000226  89260.100189
# 3  2025-01-12 09:50:00  2781.0  94565.725832   95367.536299  93712.511672
# 4  2025-01-11 04:38:00  2781.0  94700.838053   94977.687665  93840.043524
#
#            close        volume     marketCap
# 0  100504.493441  5.780592e+10  1.991112e+12
# ...

# %%
data.rename(columns = {'�timeOpen': 'timeOpen'}, inplace=True)

# %%
# Convert the 'timeOpen' column to datetime format for better handling of dates
data['timeOpen'] = pd.to_datetime(data['timeOpen'], errors='coerce')

# Filter out any rows with invalid dates or missing close prices
filtered_data = data.dropna(subset=['timeOpen', 'close'])

# Create the scatter plot
plt.figure(figsize=(12, 6))
plt.scatter(filtered_data['timeOpen'], filtered_data['close'], color='blue', alpha=0.6, label='Close Prices')

# Add labels and title
plt.xlabel('Date', fontsize=12)
plt.ylabel('Closed Prices', fontsize=12)
plt.title('Scatter Plot of Date vs. Closed Prices (2016-2025)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()
